# %%
import seaborn as sns
sns.set()

# %%
tips = sns.load_dataset('tips')

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.head(20)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
bill = tips['total_bill']

# %%
bill.max()
# Out:
# 50.81

# %%
bill.min()
# Out:
# 3.07

# %%
sns.distplot(bill , kde=False, bins=50)

# %%
# univariate
bill
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
# 5      25.29
# 6       8.77
# 7      26.88
# 8      15.04
# 9      14.78
# 10     10.27
# 11     35.26
# 12     15.42
# 13     18.43
# 14     14.83
# 15     21.58
# 16     10.33
# 17     16.29
# 18     16.97
# 19     20.65
# 20     17.92
# 21     20.29
# 22     15.77
# 23     39.42
# 24     19.82
# 25     17.81
# 26     13.37
# 27     12.69
# 28     21.70
# 29     19.65
#        ...
# 214    28.17
# 215    12.90
# 216    28.15
# 217    11.59
# 218     7.74
# 219    30.14
# 220    12.16
# 221    13.42
# 222     8.58
# 223    15.98
# 224    13.42
# 225    16.27
# 226    10.09
# 227    20.45
# 228    13.28
# 229    22.12
# 230    24.01
# 231    15.69
# 232    11.61
# 233    10.77
# 234    15.53
# 235    10.07
# 236    12.60
# 237    32.83
# 238    35.83
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# bivariate

# %%
sns.jointplot(data=tips, x='total_bill' , y='tip', kind='scatter')
# Out:
# /home/surinder/anaconda3/envs/myworkspace/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(data=tips, x='total_bill' , y='tip', kind='hex')

# %%
sns.jointplot(data=tips, x='total_bill' , y='tip', kind='reg')

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips ,  hue='sex' , palette='coolwarm')

# %%
sns.barplot(data=tips, x='sex' ,  y='total_bill' )

# %%
tips['total_bill'].mean()
# Out:
# 19.78594262295082

# %%
sns.countplot(data=tips , x='sex')

# %%
sns.boxplot(data=tips , x='day', y='total_bill', palette='rainbow')

# %%
sns.boxplot(data=tips , x='day', y='total_bill', palette='rainbow', hue='smoker')

# %%
sns.boxplot(data=tips , x='day', y='total_bill', palette='rainbow', hue='sex')

# %%
sns.violinplot(data=tips , x='day', y='total_bill', palette='rainbow', hue='sex')

# %%
sns.violinplot(data=tips , x='day', y='total_bill', palette='Set1', hue='sex')

# %%
sns.stripplot(data=tips , x='day', y='total_bill', palette='Set1', hue='sex')

# %%
sns.stripplot(data=tips , x='day', y='total_bill', palette='Set1', hue='sex', jitter=False)

# %%
sns.stripplot(data=tips , split=True, x='day', y='total_bill', palette='Set1', hue='sex', jitter=False)
# Out:
# /home/surinder/anaconda3/envs/myworkspace/lib/python3.5/site-packages/seaborn/categorical.py:2775: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(data=tips , split=True, x='day', y='total_bill', palette='Set1', hue='sex')
# Out:
# /home/surinder/anaconda3/envs/myworkspace/lib/python3.5/site-packages/seaborn/categorical.py:2974: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
flights = sns.load_dataset('flights')

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
# year          144 non-null int64
# month         144 non-null category
# passengers    144 non-null int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr() , cmap='coolwarm',  annot=True)

# %%
flights.pivot_table(index='month', columns='year', values='passengers')
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
f = flights.pivot_table(index='month', columns='year', values='passengers')

# %%
sns.heatmap(f)

# %%
sns.heatmap(f, cmap='magma', linewidths=1, linecolor='blue')

# %%
sns.clustermap(f)

# %%
sns.lmplot(x='total_bill', y='tip',  data=tips, hue='sex', row='sex', col='time')

# %%
sns.set_style('white')
sns.countplot(x='sex', data=tips)

# %%
sns.set_style('ticks')
sns.countplot(x='sex', data=tips, palette='deep')
sns.despine()
