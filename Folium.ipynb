# %%
import folium

# %%
lwmap = folium.Map(location=[26.8663122,75.7838325] , zoom_start=13, tiles="Stamen Toner"  )

# %%
folium.Marker(location=[26.8663122,75.7838325] , 
              popup='Linux World' , 
              icon=folium.Icon(color='darkblue', icon='tint', icon_color='red' ) 
             ).add_to(lwmap)

# %%
lwmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd

# %%
dataset = pd.read_excel('waterwatch_clean2.xlsx')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121 entries, 0 to 120
# Data columns (total 7 columns):
# Suburb                                            121 non-null object
# Number of single-residential properties_number    121 non-null int64
# Oct 2017
# kl/month                                 121 non-null int64
# Month                                             121 non-null object
# Year                                              121 non-null int64
# Latitude                                          121 non-null float64
# Longitude                                         121 non-null float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 7.6+ KB

# %%
dataset.columns
# Out:
# Index(['Suburb', 'Number of single-residential properties_number',
#        'Oct 2017\nkl/month', 'Month', 'Year', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
dataset.head(10)
# Out:
#             Suburb  Number of single-residential properties_number  \
# 0          ATHLONE                                            2272
# 1           AURORA                                             426
# 2       BANTRY BAY                                             248
# 3  BELLVILLE SOUTH                                            2041
# 4        BERGVLIET                                            1488
# 5     BISHOP LAVIS                                            3746
# 6     BISHOPSCOURT                                             538
# 7         BLOMTUIN                                             201
# 8      BONTEHEUWEL                                            7098
# 9         BOTHASIG                                            3399
#
#    Oct 2017\nkl/month    Month  Year   Latitude  Longitude
# 0                  11  October  2017 -33.967220  18.502140
# 1                  10  October  2017 -32.705958  18.485135
# ...

# %%
cpmap = folium.Map(location=[-33.967,18.485], zoom_start=10)

# %%
dataset.columns
# Out:
# Index(['Suburb', 'Number of single-residential properties_number',
#        'Oct 2017\nkl/month', 'Month', 'Year', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
dataset['Oct 2017\nkl/month'][0]
# Out:
# 11

# %%
dataset['Suburb'][0]
# Out:
# 'ATHLONE'

# %%
place = dataset[ ['Latitude', 'Longitude'] ]

# %%
type(place)
# Out:
# pandas.core.frame.DataFrame

# %%
# dataframe : numpy array : python list
place = place.values.tolist()

# %%
type(place)
# Out:
# list

# %%
def lw(i,color):
    folium.Marker(
            location=point, 
            popup=dataset['Suburb'][i],
            icon=folium.Icon(color=color, icon='tint', icon_color='white' )
        ).add_to(cpmap)

# %%
i=0
for point in place:
    if dataset['Oct 2017\nkl/month'][i] >= 10:
        lw(i,'red')
    else:
        lw(i,'green')
    i+=1

# %%
cpmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
cpmap.save('mymap.html')

# %%
m = folium.Map(
    location=[45.5236, -122.6750],
    tiles='Stamen Toner',
    zoom_start=13
)

folium.Circle(
    radius=200,
    location=[45.5244, -122.6699],
    popup='The Waterfront',
    color='crimson',
    fill=False,
).add_to(m)

folium.CircleMarker(
    location=[45.5215, -122.6261],
    radius=50,
    popup='Laurelhurst Park',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
